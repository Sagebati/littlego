# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 install libgoban
# Out:
# Collecting libgoban
#   Downloading https://files.pythonhosted.org/packages/80/55/cf9d6e2f2254e62a8f18200929134d0e045524098a78afd8b34347cf8b71/libgoban-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (173kB)
#      |████████████████████████████████| 174kB 2.9MB/s
# Installing collected packages: libgoban
# Successfully installed libgoban-0.7.0

# %%
import numpy as np

dataset = dataset_path+"/KGS_Chinese_Dataset_2018_11/dataset.npz"
print(dataset)

npzfile = np.load(dataset)
t_states = npzfile['states']
t_policies = npzfile['policies']
t_values = npzfile['values']
player_turn = npzfile['player_turn']

print(t_states.shape)

# %%
path = "/content/drive/My Drive/Mine/LittleGo"
algo_path = path+"/Algorithms/"
dataset_path = path+"/Datasets/"

import sys
sys.path.append(path)
sys.path.append(algo_path)

import os
os.chdir(algo_path)
# !pwd
# !ls
# Out:
# /content/drive/My Drive/Mine/LittleGo/Algorithms
# Agent.py	    __init__.py  PrioritizedSumTree.py	supervised.py
# Colab_Runner.ipynb  littlego.py  __pycache__		test__sam.py
# GoNeuralNetwork.py  ops.py	 resetModel.sh		ZeroAgent.py
# GoNNAgent.py	    ops_sgf.py	 SarstReplayMemory.py

# %%
from ops_sgf import SGF_folder_to_dataset

temp_dataset_path = dataset_path+"KGS_Chinese_Dataset_2018_11/"

SGF_folder_to_dataset(temp_dataset_path, temp_dataset_path)

# %%
# !./resetModel.sh
# Out:
# rm: cannot remove 'checkpoint': No such file or directory
# rm: cannot remove 'modelMemory.gonn.npz': No such file or directory
# rm: cannot remove 'modelParameters.gonn.npz': No such file or directory
# rm: cannot remove 'modelSumTree.gonn.npz': No such file or directory
# rm: cannot remove 'modelWeights.ckpt*': No such file or directory
# rm: cannot remove 'loss_epoch.npz': No such file or directory

# %%
temp_dataset_path = dataset_path+"KGS_Chinese_Dataset_2018_11/dataset.npz"
# !python3 ./littlego.py learn supervised "$temp_dataset_path" --data-size=2500
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# --- Initialization of Neural Network
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:100: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-02-11 13:55:36.224251: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-11 13:55:36.260307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.260938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-02-11 13:55:36.261377: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-11 13:55:36.264433: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-02-11 13:55:36.266215: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-02-11 13:55:36.266594: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-02-11 13:55:36.268823: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-02-11 13:55:36.270024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-02-11 13:55:36.274333: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-11 13:55:36.274594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.275336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.275889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-02-11 13:55:36.281249: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-02-11 13:55:36.281427: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a63100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-02-11 13:55:36.281453: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-02-11 13:55:36.394003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.394851: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1a632c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-02-11 13:55:36.394889: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2020-02-11 13:55:36.395125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.395789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# 2020-02-11 13:55:36.395863: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-11 13:55:36.395883: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-02-11 13:55:36.395898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-02-11 13:55:36.395916: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-02-11 13:55:36.395936: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-02-11 13:55:36.395951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-02-11 13:55:36.395966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-02-11 13:55:36.396061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.396717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.397284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-02-11 13:55:36.397358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-02-11 13:55:36.398651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-02-11 13:55:36.398678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-02-11 13:55:36.398690: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-02-11 13:55:36.398829: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.399501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-11 13:55:36.400059: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-02-11 13:55:36.400115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14221 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Initialized - SARST Replay Memory
# [None, 19, 19, 5]
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:140: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:141: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/ops.py:73: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/ops.py:82: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/ops.py:118: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/normalization.py:327: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/ops.py:120: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:211: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:218: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:223: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:223: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:131: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Initialized - Neural Network
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:103: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mine/LittleGo/Algorithms/GoNeuralNetwork.py:414: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Data loading
# (pre-shuffle)
# (subsample dataset) 2500
# Data shaping
# Data augmentation
# Data shuffling
# Data splitting
# Training
# (19334, 19, 19, 5)
# (19334, 362)
# (19334, 1)
# === Model saved as "./modelWeights.ckpt" ===
# === Memory saved as "./modelMemory.gonn.npz" ===
# === Parameters saved as "./modelParameters.gonn.npz" ===
#
# 2020-02-11 13:55:56.639321: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-02-11 13:55:57.000598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
#
# Minibatch 0 :
# loss = 9.79769515991211
# TRAINING  :
# policy accuracy = 0.0000
# value  error    = 1.5996
#
# VALIDATION:
# policy accuracy = 0.0090
# value  error    = 1.9985
#
# === Model saved as "./modelWeights.ckpt" ===
# === Parameters saved as "./modelParameters.gonn.npz" ===
#
#
# Minibatch 0 :
# loss = 8.772565841674805
# TRAINING  :
# policy accuracy = 0.2500
# value  error    = 2.0000
#
# VALIDATION:
# policy accuracy = 0.0150
# value  error    = 1.9985
#
#
# Minibatch 0 :
# loss = 7.225651741027832
# TRAINING  :
# policy accuracy = 0.3750
# value  error    = 2.2500
#
# VALIDATION:
# policy accuracy = 0.0180
# value  error    = 1.9985
#
#
# Minibatch 0 :
# loss = 6.878015041351318
# TRAINING  :
# policy accuracy = 0.4375
# value  error    = 1.7500
#
# VALIDATION:
# policy accuracy = 0.0210
# value  error    = 1.9985
#
#
# Minibatch 0 :
# loss = 7.807233810424805
# TRAINING  :
# policy accuracy = 0.3438
# value  error    = 2.2500
#
# Aborted!
